20% 2.4s95.5 MiB [] 21% 2.4s95.5 MiB [] 22% 2.3s95.5 MiB [] 23% 2.2s95.5 MiB [] 23% 2.3s95.5 MiB [] 24% 2.2s95.5 MiB [] 25% 2.2s95.5 MiB [] 26% 2.2s95.5 MiB [] 26% 2.1s95.5 MiB [] 27% 2.1s95.5 MiB [] 28% 2.0s95.5 MiB [] 30% 1.9s95.5 MiB [] 31% 1.9s95.5 MiB [] 32% 1.8s95.5 MiB [] 33% 1.7s95.5 MiB [] 34% 1.7s95.5 MiB [] 36% 1.6s95.5 MiB [] 37% 1.6s95.5 MiB [] 38% 1.6s95.5 MiB [] 39% 1.5s95.5 MiB [] 41% 1.4s95.5 MiB [] 44% 1.3s95.5 MiB [] 45% 1.2s95.5 MiB [] 48% 1.1s95.5 MiB [] 49% 1.1s95.5 MiB [] 51% 1.0s95.5 MiB [] 53% 1.0s95.5 MiB [] 54% 0.9s95.5 MiB [] 57% 0.9s95.5 MiB [] 59% 0.8s95.5 MiB [] 60% 0.8s95.5 MiB [] 62% 0.7s95.5 MiB [] 65% 0.7s95.5 MiB [] 67% 0.6s95.5 MiB [] 69% 0.6s95.5 MiB [] 71% 0.5s95.5 MiB [] 73% 0.5s95.5 MiB [] 75% 0.4s95.5 MiB [] 77% 0.4s95.5 MiB [] 80% 0.3s95.5 MiB [] 82% 0.3s95.5 MiB [] 84% 0.3s95.5 MiB [] 85% 0.2s95.5 MiB [] 87% 0.2s95.5 MiB [] 88% 0.2s95.5 MiB [] 90% 0.2s95.5 MiB [] 92% 0.1s95.5 MiB [] 94% 0.1s95.5 MiB [] 95% 0.1s95.5 MiB [] 97% 0.0s95.5 MiB [] 98% 0.0s95.5 MiB [] 100% 0.0s
# Webkit 18.2 (playwright build v2104) downloaded to /root/.cache/ms-playwright/webkit-2104
# Downloading FFMPEG playwright build v1010 from https://playwright.azureedge.net/builds/ffmpeg/1010/ffmpeg-linux.zip
# 2.3 MiB [] 0% 0.0s2.3 MiB [] 3% 0.6s2.3 MiB [] 11% 0.3s2.3 MiB [] 24% 0.2s2.3 MiB [] 62% 0.0s2.3 MiB [] 100% 0.0s
# FFMPEG playwright build v1010 downloaded to /root/.cache/ms-playwright/ffmpeg-1010
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libavif.so.13                                    ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:216:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:753:43)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:851:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:840:43)
#     at async t.<anonymous> (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/cli/program.js:137:7)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 49 not upgraded.
# Need to get 7,815 kB of archives.
# After this operation, 11.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.12 [28.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.12 [864 kB]
# Fetched 7,815 kB in 1s (7,744 kB/s)
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 123634 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../3-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../4-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../5-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../6-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../7-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.12_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../8-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link

# %%
import os
os.system("Xvfb :99 -screen 0 1024x768x24 &")
os.environ["DISPLAY"] = ":99"

# %%
#We install dependencies
# !pip install playwright
from playwright.async_api import async_playwright
import asyncio
import csv
import json
# Install the required browsers
# !python3 -m playwright install
# Out:
# Requirement already satisfied: playwright in /usr/local/lib/python3.10/dist-packages (1.49.1)
# Requirement already satisfied: greenlet==3.1.1 in /usr/local/lib/python3.10/dist-packages (from playwright) (3.1.1)
# Requirement already satisfied: pyee==12.0.0 in /usr/local/lib/python3.10/dist-packages (from playwright) (12.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee==12.0.0->playwright) (4.12.2)
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libavif.so.13                                    ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:216:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:753:43)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:851:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:840:43)
#     at async t.<anonymous> (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/cli/program.js:137:7)

# %%
"""import asyncio
import csv
from playwright.async_api import async_playwright

async def scrape_amazon_smartphones():
    start_url = "https://www.amazon.com/s?k=smartphones"

    async with async_playwright() as p:
        # Launch browser with a little header specification to probably bypass amazon
        browser = await p.chromium.launch(headless=False)
        context = await browser.new_context(user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36")
        page = await context.new_page()

        # Open CSV file for writing
        with open("amazon_smartphones.csv", "w", newline="", encoding="utf-8") as csvfile:
            fieldnames = ["Product Name", "Price", "Rating", "Number of Reviews","Amount of products sold out", "Product Link"]
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()

            # Navigate to the start URL
            await page.goto(start_url)
            print("Navigated to Amazon smartphone page successfully!")

            while True:
                # Wait for smartphones product listings to load and set a mx timeout to a minute
                await page.wait_for_selector("div.s-main-slot", timeout=60000)

                # Locate product elements
                products = page.locator('div[class="sg-col-inner"]')
                product_count = await products.count()

                for i in range(product_count):
                    try:
                        # Extract product details
                        name = await products.nth(i).locator('h2[class="a-section aok-relative s-image-fixed-height"]').inner_text() if await products.nth(i).locator('h2[class="a-section aok-relative s-image-fixed-height"]').count() > 0 else "N/A"
                        price = await products.nth(i).locator('span[class="a-offscreen"]').inner_text() if await products.nth(i).locator('span[class="a-offscreen"]').count() > 0 else "N/A"
                        reviews = await products.nth(i).locator('span[class="a-size-base s-underline-text"]').inner_text() if await products.nth(i).locator('span[class="a-size-base s-underline-text"]').count() > 0 else "N/A"
                        rating = await products.nth(i).locator('span[class="a-icon-alt"]').inner_text() if await products.nth(i).locator('span[class="a-icon-alt"]').count() > 0 else "N/A"
                        link = await products.nth(i).locator('a[class="a-link-normal s-line-clamp-2 s-link-style a').get_attribute("href") if await products.nth(i).locator('a[class="a-link-normal s-line-clamp-2 s-link-style a').count() > 0 else "N/A"
                        sold = await products.nth(i).locator('span[class="a-size-base a-color-secondary"]').inner_text() if await products.nth(i).locator('span[class="a-size-base a-color-secondary"]').count() > 0 else "N/A"


                        # We save product details to a CSV file
                        writer.writerow({
                            "Product Name": name,
                            "Price": price,
                            "Rating": rating,
                            "Number of Reviews": reviews,
                            "Amount of products sold out": sold,
                            "Product Link": f"https://www.amazon.com{link}" if link != "N/A" else "N/A" #this wounf render a complete clickable link
                        })
                    except Exception as e:
                        print(f"Error scraping product {i + 1}: {e}")

                # Check for "Next" button within a present pave
                next_button = page.locator('a[class="s-pagination-item s-pagination-next s-pagination-button s-pagination-button-accessibility s-pagination-separator"]')
                if await next_button.is_visible():
                    print("Navigating to the next page...")
                    await next_button.click()
                    await asyncio.sleep(5)  # Wait for the next page to load for about 5secs
                else:
                    print("No more pages to scrape")
                    break

        # Close the browser
        await browser.close()
        print("Scraping completed. Data saved to 'amazon_smartphones.csv'")

# Run the scraper function to the moon yoooooooo hopefully!
await scrape_amazon_smartphones()"""
# Out:
# 'import asyncio\nimport csv\nfrom playwright.async_api import async_playwright\n\nasync def scrape_amazon_smartphones():\n    start_url = "https://www.amazon.com/s?k=smartphones"\n\n    async with async_playwright() as p:\n        # Launch browser with a little header specification to probably bypass amazon\n        browser = await p.chromium.launch(headless=False)\n        context = await browser.new_context(user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36")\n        page = await context.new_page()\n\n        # Open CSV file for writing\n        with open("amazon_smartphones.csv", "w", newline="", encoding="utf-8") as csvfile:\n            fieldnames = ["Product Name", "Price", "Rating", "Number of Reviews","Amount of products sold out", "Product Link"]\n            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)\n            writer.writeheader()\n\n            # Navigate to the start URL\n            await page.goto(start_url)\n            print("Navigated to Amazon smartphone page successfully!")\n\n            while True:\n                # Wait for smartphones product listings to load and set a mx timeout to a minute\n                await page.wait_for_selector("div.s-main-slot", timeout=60000)\n\n                # Locate product elements\n                products = page.locator(\'div[class="sg-col-inner"]\')\n                product_count = await products.count()\n\n                for i in range(product_count):\n                    try:\n                        # Extract product details\n                        name = await products.nth(i).locator(\'h2[class="a-section aok-relative s-image-fixed-height"]\').inner_text() if await products.nth(i).locator(\'h2[class="a-section aok-relative s-image-fixed-height"]\').count() > 0 else "N/A"\n                        price = await products.nth(i).locator(\'span[class="a-offscreen"]\').inner_text() if await products.nth(i).locator(\'span[class="a-offscreen"]\').count() > 0 else "N/A"\n                        reviews = await products.nth(i).locator(\'span[class="a-size-base s-underline-text"]\').inner_text() if await products.nth(i).locator(\'span[class="a-size-base s-underline-text"]\').count() > 0 else "N/A"\n                        rating = await products.nth(i).locator(\'span[class="a-icon-alt"]\').inner_text() if await products.nth(i).locator(\'span[class="a-icon-alt"]\').count() > 0 else "N/A"\n                        link = await products.nth(i).locator(\'a[class="a-link-normal s-line-clamp-2 s-link-style a\').get_attribute("href") if await products.nth(i).locator(\'a[class="a-link-normal s-line-clamp-2 s-link-style a\').count() > 0 else "N/A"\n                        sold = await products.nth(i).locator(\'span[class="a-size-base a-color-secondary"]\').inner_text() if await products.nth(i).locator(\'span[class="a-size-base a-color-secondary"]\').count() > 0 else "N/A"\n\n\n                        # We save product details to a CSV file\n                        writer.writerow({\n                            "Product Name": name,\n                            "Price": price,\n                            "Rating": rating,\n                            "Number of Reviews": reviews,\n                            "Amount of products sold out": sold,\n                            "Product Link": f"https://www.amazon.com{link}" if link != "N/A" else "N/A" #this wounf render a complete clickable link\n                        })\n                    except Exception as e:\n                        print(f"Error scraping product {i + 1}: {e}")\n\n                # Check for "Next" button within a present pave\n                next_button = page.locator(\'a[class="s-pagination-item s-pagination-next s-pagination-button s-pagination-button-accessibility s-pagination-separator"]\')\n                if await next_button.is_visible():\n                    print("Navigating to the next page...")\n                ...

# %%
import json
import csv
#Now lets view the contents of our cookies.json file
with open("cooks.json" ,'r') as file:
    cookies = json.load(file)
    for cookie in cookies:
        print(cookie)
    cookies

# %%
async def login_amazon_account():
    with open("cooks.json", 'r') as file:
        cookies_data = json.load(file)

    async with async_playwright() as p:

        browser = await p.chromium.launch(headless=True)
        context =  await browser.new_context()
        await context.add_cookies(cookies_data)
        page = await context.new_page()
        await page.goto("https://www.amazon.com")
        print("Navigated to amazon successfully, Now locating the sign up botton")
        await page.screenshot(path= "nice_one.png")
        print("Screenshoted the bastard")
        print("Clicked the sign up botton successfully,Tryimg you fill in the email")

        search_box= page.locator('input[id="twotabsearchtextbox"]')
        await search_box.fill("smartphones")
        search_bar = page.locator('input[id="nav-search-submit-button"]')
        await search_bar.click()

        await page.wait_for_selector('h2[class="a-size-medium-plus a-spacing-none a-color-base a-text-bold"]')
        print("Search results and varieties of smartphones with yheir specifications Consoled brother")
        await page.screenshot(path="results.png")

        with open("amazon_smartphones.csv", "w", newline="", encoding="utf-8") as csvfile:
            fieldnames = ["Product Name", "Price", "Rating", "Number of Reviews","Amount of products sold out", "Product Link", "Actual listed price"]
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()

            while True:

                #Locate product elements
                products = page.locator('div[class="sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col s-widget-spacing-small sg-col-12-of-16"]')
                product_count = await products.count()
                for i in range(product_count):
                    try:
                        #Extract products details
                        name = await products.nth(i).locator('h2[class="a-size-medium a-spacing-none a-color-base a-text-normal"]').inner_text() if await products.nth(i).locator('h2[class="a-size-medium a-spacing-none a-color-base a-text-normal"]').count() > 0 else "N/A"
                        price = await products.nth(i).locator('span[class="a-price-whole"]').inner_text() if await products.nth(i).locator('span[class="a-price-whole"]').count() > 0 else "N/A"
                        reviews = await products.nth(i).locator('span[class="a-size-small puis-normal-weight-text s-underline-text"]').inner_text() if await products.nth(i).locator('span[class="a-size-small puis-normal-weight-text s-underline-text"]').count() > 0 else "N/A"
                        rating = await products.nth(i).locator('span[class="a-icon-alt"]').inner_text() if await products.nth(i).locator('span[class="a-icon-alt"]').count() > 0 else "N/A"
                        link = await products.nth(i).locator('a[class="a-link-normal s-line-clamp-2 s-link-style a-text-normal"]').get_attribute("href") if await products.nth(i).locator('a[class="a-link-normal s-line-clamp-2 s-link-style a-text-normal"]').count() > 0 else "N/A"
                        sold = await products.nth(i).locator('div[class="a-row a-size-base"]').inner_text() if await products.nth(i).locator('div[class="a-row a-size-base"]').count() > 0 else "N/A"
                        list_price = await products.nth(i).locator('span[class="a-price a-text-price"] span[class="a-offscreen"]').inner_text() if await products.nth(i).locator('span[class="a-price a-text-price"] span[class="a-offscreen"]').count() > 0 else "N/A"

                        writer.writerow({
                            "Product Name": name,
                            "Price": price,
                            "Rating": rating,
                            "Number of Reviews": reviews,
                            "Amount of products sold out": sold,
                            "Product Link": f"https://www.amazon.com{link}" if link != "N/A" else "N/A", #this wounf render a complete clickable link
                            "Actual listed price": list_price
                                    })
                    except Exception as e:
                        print(f"Error scraping product {i+1}: {e}")

                # Check for "Next" button within a present pave
                next_button = page.locator('a[class="s-pagination-item s-pagination-next s-pagination-button s-pagination-button-accessibility s-pagination-separator"]')
                if await next_button.is_visible():
                    print("Navigating to the next page...")
                    await next_button.click()
                    await asyncio.sleep(5)  # Wait for the next page to load for about 5secs
                else:
                    print("No more pages to scrape")
                    break

        # Close the browser
        await browser.close()
        print("Scraping completed. Data saved to 'amazon_smartphones.csv'")



if __name__ == "__main__":
    await login_amazon_account()
# Out:
# Navigated to amazon successfully, Now locating the sign up botton
# Screenshoted the bastard
# Clicked the sign up botton successfully,Tryimg you fill in the email
# Search results and varieties of smartphones with yheir specifications Consoled brother
# Navigating to the next page...
# Error scraping product 13: Locator.inner_text: Error: strict mode violation: locator("div[class=\"sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col s-widget-spacing-small sg-col-12-of-16\"]").nth(12).locator("div[class=\"a-row a-size-base\"]") resolved to 2 elements:
#     1) <div class="a-row a-size-base">…</div> aka locator("div").filter(has_text=re.compile(r"^Top Reviewed for Sound quality$")).nth(2)
#     2) <div class="a-row a-size-base">…</div> aka locator("[id=\"\\38 6154133-8250-4f6d-a802-3b756998076c\"] div").filter(has_text=re.compile(r"^500\+ bought in past month$"))
#
# Call log:
#   - waiting for locator("div[class=\"sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col s-widget-spacing-small sg-col-12-of-16\"]").nth(12).locator("div[class=\"a-row a-size-base\"]")
#
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# Navigating to the next page...
# No more pages to scrape
# Scraping completed. Data saved to 'amazon_smartphones.csv'

# %%
import pandas as pd
df = pd.read_csv("amazon_smartphones.csv")
df
# Out:
#                                           Product Name     Price  \
# 0    Samsung Galaxy A15 A155M 128GB Dual-SIM GSM Un...    149\n.
# 1    Samsung Galaxy S24 Ultra Cell Phone, 512GB AI ...  1,169\n.
# 2    SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...    174\n.
# 3    Moto G 5G | 2024 | Unlocked | Made for US 4/12...    149\n.
# 4    Google Pixel 8a - Unlocked Android Phone with ...    490\n.
# ..                                                 ...       ...
# 300  DOOGEE Blade 10 Rugged Smartphone Unlocked, 10...    199\n.
# 301  I16 PRO MAX Android Phone, 8GB+256GB Unlocked ...    139\n.
# 302  S24 Unlocked Cell Phone, 4GB+128GB Smartphone ...    149\n.
# 303  Mini Smartphone, Child Phone The World's Small...     49\n.
# 304  Unlocked Smartphone 6.7inch Cell Phone S22 Ult...     89\n.
#
#                  Rating Number of Reviews Amount of products sold out  \
# 0    4.3 out of 5 stars             (797)    4K+ bought in past month
# 1    4.5 out of 5 stars            (3.8K)    2K+ bought in past month
# 2    4.1 out of 5 stars              (1K)    1K+ bought in past month
# 3    4.1 out of 5 stars            (1.2K)    5K+ bought in past month
# 4    4.2 out of 5 stars             (771)    3K+ bought in past month
# ..                  ...               ...                         ...
# 300  5.0 out of 5 stars               (2)                         NaN
# 301  5.0 out of 5 stars               (2)                         NaN
# 302                 NaN               NaN                         NaN
# 303  3.2 out of 5 stars              (88)   200+ bought in past month
# 304  2.3 out of 5 stars             (159)                         NaN
#
#                                           Product Link Actual listed price
# 0    https://www.amazon.com/Samsung-SM-155M-DSN-Unl...                 NaN
# 1    https://www.amazon.com/SAMSUNG-Smartphone-Unlo...           $1,419.99
# 2    https://www.amazon.com/SAMSUNG-Unlocked-Smartp...             $199.99
# 3    https://www.amazon.com/Moto-Unlocked-128GB-Cam...             $199.99
# 4    https://www.amazon.com/Google-Pixel-8a-Unlocke...                 NaN
# ..                                                 ...                 ...
# 300  https://www.amazon.com/DOOGEE-Smartphone-Unloc...                 NaN
# 301  https://www.amazon.com/I16-PRO-MAX-Unlocked-Sm...                 NaN
# 302  https://www.amazon.com/luckeu-S24-Unlocked-Sma...                 NaN
# 303  https://www.amazon.com/Cutwif-Smartphone-Small...                 NaN
# 304  https://www.amazon.com/Unlocked-Smartphone-6-7...                 NaN
#
# [305 rows x 7 columns]

# %%
#Now lets clean up and emsure consistency within our scraped data
#Firstly we should attach the $ sign to the price column
df["Price"] = "$" + df["Price"].astype(str)
df["Price"] = df["Price"].str.replace("\n", "").str.replace(".", "")
df["Number of Reviews"] = df["Number of Reviews"].str.replace(")", "").str.replace("(", "")

df.to_csv("amazon_smartphones.csv", index=False)
df
# Out:
#                                           Product Name   Price  \
# 0    Samsung Galaxy A15 A155M 128GB Dual-SIM GSM Un...    $149
# 1    Samsung Galaxy S24 Ultra Cell Phone, 512GB AI ...  $1,169
# 2    SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...    $174
# 3    Moto G 5G | 2024 | Unlocked | Made for US 4/12...    $149
# 4    Google Pixel 8a - Unlocked Android Phone with ...    $490
# ..                                                 ...     ...
# 300  DOOGEE Blade 10 Rugged Smartphone Unlocked, 10...    $199
# 301  I16 PRO MAX Android Phone, 8GB+256GB Unlocked ...    $139
# 302  S24 Unlocked Cell Phone, 4GB+128GB Smartphone ...    $149
# 303  Mini Smartphone, Child Phone The World's Small...     $49
# 304  Unlocked Smartphone 6.7inch Cell Phone S22 Ult...     $89
#
#                  Rating Number of Reviews Amount of products sold out  \
# 0    4.3 out of 5 stars               797    4K+ bought in past month
# 1    4.5 out of 5 stars              3.8K    2K+ bought in past month
# 2    4.1 out of 5 stars                1K    1K+ bought in past month
# 3    4.1 out of 5 stars              1.2K    5K+ bought in past month
# 4    4.2 out of 5 stars               771    3K+ bought in past month
# ..                  ...               ...                         ...
# 300  5.0 out of 5 stars                 2                         NaN
# 301  5.0 out of 5 stars                 2                         NaN
# 302                 NaN               NaN                         NaN
# 303  3.2 out of 5 stars                88   200+ bought in past month
# 304  2.3 out of 5 stars               159                         NaN
#
#                                           Product Link Actual listed price
# 0    https://www.amazon.com/Samsung-SM-155M-DSN-Unl...                 NaN
# 1    https://www.amazon.com/SAMSUNG-Smartphone-Unlo...           $1,419.99
# 2    https://www.amazon.com/SAMSUNG-Unlocked-Smartp...             $199.99
# 3    https://www.amazon.com/Moto-Unlocked-128GB-Cam...             $199.99
# 4    https://www.amazon.com/Google-Pixel-8a-Unlocke...                 NaN
# ..                                                 ...                 ...
# 300  https://www.amazon.com/DOOGEE-Smartphone-Unloc...                 NaN
# 301  https://www.amazon.com/I16-PRO-MAX-Unlocked-Sm...                 NaN
# 302  https://www.amazon.com/luckeu-S24-Unlocked-Sma...                 NaN
# 303  https://www.amazon.com/Cutwif-Smartphone-Small...                 NaN
# 304  https://www.amazon.com/Unlocked-Smartphone-6-7...                 NaN
#
# [305 rows x 7 columns]

# %%
from google.colab import files
files.download("amazon_smartphones.csv")
